# %% [markdown]
# <a href="https://colab.research.google.com/github/Vandanamchauhan/MLProjects/blob/opencv/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab.patches import cv2_imshow
import cv2 


 
img = cv2.imread("/content/drive/MyDrive/OpenCVphotos/falcon.jpg")

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7F1F26893610>
